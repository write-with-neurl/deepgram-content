# %% [markdown]
# <div align="center" dir="auto">
# <p dir="auto">
#
# <a href="https://colab.research.google.com/github/write-with-neurl/deepgram-content/blob/main/MultimodalAI/Finetuning_Idefics_9B.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>
#
# </p>

# %% [markdown]
# # ⚡ [Deepgram] Finetuning IDEFICS 9B LLM for image description of Pokemon Go images

# %% [markdown]
# In this example, we fine-tune IDEFICS on a Pokémon Go dataset from Hugging Face. [IDEFICS](https://huggingface.co/docs/transformers/main/en/tasks/idefics) is an open-access vision and language model based on [Flamingo](https://huggingface.co/papers/2204.14198), a state-of-the-art visual language model initially developed by DeepMind. The model accepts arbitrary sequences of image and text inputs, generating coherent text as output. It can answer questions about images, describe visual content, and create stories grounded in multiple images.
#
#
# > Check out the accompanying article for this notebook "Multimodal AI in Action" on the [Deepgram blog](https://deepgram.com/learn/article).

# %% [markdown]
# ## 🧑‍💻 Installations and Set Up

# %%
# !pip install -q datasets
# !pip install -q git+https://github.com/huggingface/transformers
# !pip install -q bitsandbytes sentencepiece accelerate loralib
# !pip install -q -U git+https://github.com/huggingface/peft.git
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 510.5/510.5 kB 6.9 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 116.3/116.3 kB 11.6 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 134.8/134.8 kB 11.5 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
#   Building wheel for transformers (pyproject.toml) ... done
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 102.2/102.2 MB 16.7 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 280.0/280.0 kB 33.0 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
#   Building wheel for peft (pyproject.toml) ... done

# %%
import torch
from datasets import load_dataset
from peft import LoraConfig, get_peft_model
from PIL import Image
from transformers import IdeficsForVisionText2Text, AutoProcessor, Trainer, TrainingArguments, BitsAndBytesConfig
import torchvision.transforms as transforms

# %% [markdown]
# ## ⏳ Loading and Quantization of Idefics 9B
# Since high-memory GPU availability may be a concern, we opt to load the quantized version of the model. To load the model and the processor in 4-bit precision, we pass a BitsAndBytesConfig to the `from_pretrained` method, and the model will compress on the fly during loading.

# %%
device = "cuda" if torch.cuda.is_available() else "cpu"

# %%
checkpoint = "HuggingFaceM4/idefics-9b"

# %%
bnb_config = BitsAndBytesConfig(
    load_in_4bit=True,
    bnb_4bit_use_double_quant=True,
    bnb_4bit_quant_type="nf4",
    bnb_4bit_compute_dtype=torch.float16,
    llm_int8_skip_modules=["lm_head", "embed_tokens"]
)

# %%
processor = AutoProcessor.from_pretrained(checkpoint)
# Out:
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_token.py:88: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# preprocessor_config.json:   0%|          | 0.00/281 [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/1.36k [00:00<?, ?B/s]
# tokenizer.model:   0%|          | 0.00/500k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/1.84M [00:00<?, ?B/s]
# added_tokens.json:   0%|          | 0.00/61.0 [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/181 [00:00<?, ?B/s]
# Special tokens have been added in the vocabulary, make sure the associated word embeddings are fine-tuned or trained.

# %%
model = IdeficsForVisionText2Text.from_pretrained(checkpoint, quantization_config=bnb_config, device_map="auto")
# Out:
# config.json:   0%|          | 0.00/1.41k [00:00<?, ?B/s]
# model.safetensors.index.json:   0%|          | 0.00/99.2k [00:00<?, ?B/s]
# Downloading shards:   0%|          | 0/19 [00:00<?, ?it/s]
# model-00001-of-00019.safetensors:   0%|          | 0.00/2.00G [00:00<?, ?B/s]
# model-00002-of-00019.safetensors:   0%|          | 0.00/1.82G [00:00<?, ?B/s]
# model-00003-of-00019.safetensors:   0%|          | 0.00/1.98G [00:00<?, ?B/s]
# model-00004-of-00019.safetensors:   0%|          | 0.00/1.93G [00:00<?, ?B/s]
# model-00005-of-00019.safetensors:   0%|          | 0.00/1.93G [00:00<?, ?B/s]
# model-00006-of-00019.safetensors:   0%|          | 0.00/1.98G [00:00<?, ?B/s]
# model-00007-of-00019.safetensors:   0%|          | 0.00/1.89G [00:00<?, ?B/s]
# model-00008-of-00019.safetensors:   0%|          | 0.00/1.98G [00:00<?, ?B/s]
# model-00009-of-00019.safetensors:   0%|          | 0.00/1.93G [00:00<?, ?B/s]
# model-00010-of-00019.safetensors:   0%|          | 0.00/1.93G [00:00<?, ?B/s]
# model-00011-of-00019.safetensors:   0%|          | 0.00/1.98G [00:00<?, ?B/s]
# model-00012-of-00019.safetensors:   0%|          | 0.00/1.89G [00:00<?, ?B/s]
# model-00013-of-00019.safetensors:   0%|          | 0.00/1.98G [00:00<?, ?B/s]
# model-00014-of-00019.safetensors:   0%|          | 0.00/1.93G [00:00<?, ?B/s]
# model-00015-of-00019.safetensors:   0%|          | 0.00/1.93G [00:00<?, ?B/s]
# model-00016-of-00019.safetensors:   0%|          | 0.00/1.97G [00:00<?, ?B/s]
# model-00017-of-00019.safetensors:   0%|          | 0.00/1.98G [00:00<?, ?B/s]
# model-00018-of-00019.safetensors:   0%|          | 0.00/1.97G [00:00<?, ?B/s]
# model-00019-of-00019.safetensors:   0%|          | 0.00/705M [00:00<?, ?B/s]
# Loading checkpoint shards:   0%|          | 0/19 [00:00<?, ?it/s]
# generation_config.json:   0%|          | 0.00/137 [00:00<?, ?B/s]

# %%
model
# Out:
# IdeficsForVisionText2Text(
#   (model): IdeficsModel(
#     (embed_tokens): IdeficsDecoupledEmbedding(
#       num_embeddings=32000, num_additional_embeddings=2, embedding_dim=4096, partially_freeze=False
#       (additional_embedding): Embedding(2, 4096)
#     )
#     (vision_model): IdeficsVisionTransformer(
#       (embeddings): IdeficsVisionEmbeddings(
#         (patch_embedding): Conv2d(3, 1280, kernel_size=(14, 14), stride=(14, 14), bias=False)
#         (position_embedding): Embedding(257, 1280)
#       )
#       (pre_layrnorm): LayerNorm((1280,), eps=1e-05, elementwise_affine=True)
#       (encoder): IdeficsVisionEncoder(
#         (layers): ModuleList(
#           (0-31): 32 x IdeficsVisionEncoderLayer(
#             (self_attn): IdeficsVisionAttention(
#               (k_proj): Linear4bit(in_features=1280, out_features=1280, bias=True)
#               (v_proj): Linear4bit(in_features=1280, out_features=1280, bias=True)
#               (q_proj): Linear4bit(in_features=1280, out_features=1280, bias=True)
#               (out_proj): Linear4bit(in_features=1280, out_features=1280, bias=True)
#             )
#             (layer_norm1): LayerNorm((1280,), eps=1e-05, elementwise_affine=True)
#             (mlp): IdeficsVisionMLP(
#               (activation_fn): GELUActivation()
#               (fc1): Linear4bit(in_features=1280, out_features=5120, bias=True)
#               (fc2): Linear4bit(in_features=5120, out_features=1280, bias=True)
#             )
#             (layer_norm2): LayerNorm((1280,), eps=1e-05, elementwise_affine=True)
#           )
#         )
#       )
#       (post_layernorm): LayerNorm((1280,), eps=1e-05, elementwise_affine=True)
#     )
#     (perceiver_resampler): IdeficsPerceiverResampler(
#       (blocks): ModuleList(
#         (0-5): 6 x ModuleList(
#           (0): IdeficsPerceiverAttention(
#             (context_layer_norm): LayerNorm((1280,), eps=1e-05, elementwise_affine=True)
#             (latents_layer_norm): LayerNorm((1280,), eps=1e-05, elementwise_affine=True)
#             (q_layer_norm): LayerNorm((96,), eps=1e-05, elementwise_affine=True)
#             (k_layer_norm): LayerNorm((96,), eps=1e-05, elementwise_affine=True)
#             (q_proj): Linear4bit(in_features=1280, out_features=1536, bias=False)
#             (k_proj): Linear4bit(in_features=1280, out_features=1536, bias=False)
#             (v_proj): Linear4bit(in_features=1280, out_features=1536, bias=False)
#             (output_proj): Linear4bit(in_features=1536, out_features=1280, bias=False)
#           )
#           (1): IdeficsMLP(
#             (ln): LayerNorm((1280,), eps=1e-05, elementwise_affine=True)
#             (fc): Linear4bit(in_features=1280, out_features=5120, bias=False)
#             (act): ReLU()
#             (c_proj): Linear4bit(in_features=5120, out_features=1280, bias=False)
#           )
#         )
#       )
#       (layer_norm): LayerNorm((1280,), eps=1e-05, elementwise_affine=True)
#     )
#     (layers): ModuleList(
#       (0-31): 32 x IdeficsDecoderLayer(
#         (self_attn): IdeficsAttention(
#           (q_proj): Linear4bit(in_features=4096, out_features=4096, bias=False)
#           (k_proj): Linear4bit(in_features=4096, out_features=4096, bias=False)
#           (v_proj): Linear4bit(in_features=4096, out_features=4096, bias=False)
#           (o_proj): Linear4bit(in_features=4096, out_features=4096, bias=False)
#           (rotary_emb): IdeficsEmbedding()
#         )
#         (mlp): IdeficsMLP(
#           (gate_proj): Linear4bit(in_features=4096, out_features=11008, bias=False)
#           (down_proj): Linear4bit(in_features=11008, out_features=4096, bias=False)
#           (up_proj): Linear4bit(in_features=4096, out_features=11008, bias=False)
#           (act_fn): SiLU()
#         )
#         (input_layernorm): IdeficsRMSNorm()
#         (post_attention_layernorm): IdeficsRMSNorm()
#       )
#     )
#     (gated_cross_attn_layers): ModuleList(
#       (0-7): 8 x IdeficsGatedCrossAttentionLayer(
#         (cross_attn): IdeficsAttention(
#           (q_proj): Linear4bit(in_features=4096, out_features=4096, bias=False)
#           (k_proj): Linear4bit(in_features=1280, out_features=4096, bias=False)
#           (v_proj): Linear4bit(in_features=1280, out_features=4096, bias=False)
#           (o_proj): Linear4bit(in_features=4096, out_features=4096, bias=False)
#           (rotary_emb): IdeficsEmbedding()
#           (q_layer_norm): IdeficsRMSNorm()
#           (k_layer_norm): IdeficsRMSNorm()
#         )
#         (mlp): IdeficsMLP(
#           (gate_proj): Linear4bit(in_features=4096, out_features=11008, bias=False)
#           (down_proj): Linear4bit(in_features=11008, out_features=4096, bias=False)
#           (up_proj): Linear4bit(in_features=4096, out_features=11008, bias=False)
#           (act_fn): SiLU()
#         )
#         (input_layernorm): IdeficsRMSNorm()
#         (post_attention_layernorm): IdeficsRMSNorm()
#         (act_cross_attn): Tanh()
#         (act_dense): Tanh()
#       )
#     )
#     (norm): IdeficsRMSNorm()
#   )
#   (lm_head): IdeficsDecoupledLinear(
#     in_features=4096, out_features=32000, out_additional_features=2, bias=False, partially_freeze=False
#     (additional_fc): Linear(in_features=4096, out_features=2, bias=False)
#   )
# )

# %% [markdown]
# ## Inference Function for Generating Responses
# This function, `do_inference`, carries out the inference process for the 4-bit quantized Idefics 9B model and processor with specified prompts. It initializes a tokenizer from the processor to encode prompts and specify tokens that are not desirable in the output (bad words). If any such tokens are listed, their IDs are retrieved. The function also defines an end-of-sequence token to signal the model when to stop generating further tokens. It then encodes the prompts into input tensors compatible with the model and generates a sequence of IDs representing the continuation of the prompts, avoiding the bad words, and stopping after a maximum number of new tokens or when the end-of-sequence token is reached. Finally, it decodes the generated IDs back into text and prints the result, ensuring any special tokens are not included in the output.

# %%
# Inference
def do_inference(model, processor, prompts, max_new_tokens=50):
    tokenizer = processor.tokenizer
    bad_words = ["", "<fake_token_around_image>"]
    if len(bad_words) > 0:
        bad_words_ids = tokenizer(bad_words, add_special_tokens=False).input_ids
    eos_token = "</s>"
    eos_token_id = tokenizer.convert_tokens_to_ids(eos_token)

    inputs = processor(prompts, return_tensors="pt").to(device)
    generated_ids = model.generate(
        **inputs,
        eos_token_id=[eos_token_id],
        bad_words_ids=bad_words_ids,
        max_new_tokens=max_new_tokens,
        early_stopping=True
    )
    generated_text = processor.batch_decode(generated_ids, skip_special_tokens=True)[0]
    print(generated_text)

# %%
url = "https://hips.hearstapps.com/hmg-prod/images/cute-photos-of-cats-in-grass-1593184777.jpg"
prompts = [
    url,
    "Question: What's on the picture? Answer:",
]

# %%
do_inference(model, processor, prompts, max_new_tokens=50)
# Out:
# /usr/local/lib/python3.10/dist-packages/transformers/generation/configuration_utils.py:535: UserWarning: `num_beams` is set to 1. However, `early_stopping` is set to `True` -- this flag is only used in beam-based generation modes. You should set `num_beams>1` or unset `early_stopping`.
#   warnings.warn(
# Question: What's on the picture? Answer: Two kittens playing in the grass.

# %% [markdown]
# # 🛠 Finetuning Setup

# %% [markdown]
# ## Preprocessing of Pokemon Go dataset

# %% [markdown]
# The function `convert_to_rgb` ensures that any given image is in the RGB color space. If the image is already in RGB, it is returned as is; if not, it converts the image to RGBA to blend it with a white background, effectively removing any transparency, before converting it to RGB.

# %%
def convert_to_rgb(image):
  if image.mode == "RGB":
    return image

  image_rgba = image.convert("RGBA")
  background = Image.new("RGBA", image_rgba.size, (255,255,255))
  alpha_composite = Image.alpha_composite(background, image_rgba)
  alpha_composite = alpha_composite.convert("RGB")
  return alpha_composite

# %% [markdown]
# `ds_transforms` is a preprocessing function that takes a batch of examples, each consisting of image URLs, captions, and names. It defines a series of image transformations, including conversion to RGB, random cropping, and normalization using predefined parameters from a processor. For each example, it extracts a prompt from the caption and forms a question-answer pair that includes the name and a statement about the image. These prompts are then processed along with the transformed images into tensors ready for input into a model, also setting the input IDs as labels for supervised training. The function concludes by returning the processed inputs and labels, prepared for the model.

# %%
def ds_transforms(example_batch):
  image_size = processor.image_processor.image_size
  image_mean = processor.image_processor.image_mean
  image_std = processor.image_processor.image_std

  image_transform = transforms.Compose([
      convert_to_rgb,
      transforms.RandomResizedCrop((image_size, image_size), scale=(0.9, 1.0), interpolation=transforms.InterpolationMode.BICUBIC),
      transforms.ToTensor(),
      transforms.Normalize(mean=image_mean, std=image_std)
  ])

  prompts = []
  print(example_batch)
  for i in range(len(example_batch['caption'])):
    caption = example_batch['caption'][i].split(".")[0]
    prompts.append(
        [
            example_batch['image_url'][i],
            f"Question: What's on the picture? Answer: This is {example_batch['name']}. {caption}",
        ],
    )
  inputs = processor(prompts, transform=image_transform, return_tensors="pt").to(device)
  inputs["labels"] = inputs["input_ids"]
  return inputs

# %% [markdown]
# ## Load and prepare the data

# %%
ds = load_dataset("TheFusion21/PokemonCards")
ds = ds["train"].train_test_split(test_size=0.002)
train_ds = ds["train"]
eval_ds = ds["test"]
train_ds.set_transform(ds_transforms)
eval_ds.set_transform(ds_transforms)

# %%
model_name = checkpoint.split("/")[1]
config = LoraConfig(
    r = 16,
    lora_alpha = 32,
    target_modules = ["q_proj", "k_proj", "v_proj"],
    lora_dropout = 0.05,
    bias="none"
)

# %%
model = get_peft_model(model, config)

# %%
model.print_trainable_parameters()
# Out:
# trainable params: 19,750,912 || all params: 8,949,430,544 || trainable%: 0.2206946230030432

# %%
training_args = TrainingArguments(
    output_dir = f"{model_name}-PokemonCards",
    learning_rate = 2e-4,
    fp16 = True,
    per_device_train_batch_size = 2,
    per_device_eval_batch_size = 2,
    gradient_accumulation_steps = 8,
    dataloader_pin_memory = False,
    save_total_limit = 3,
    evaluation_strategy ="steps",
    save_strategy = "steps",
    eval_steps = 10,
    save_steps = 25,
    max_steps = 25,
    logging_steps = 5,
    remove_unused_columns = False,
    push_to_hub=False,
    label_names = ["labels"],
    load_best_model_at_end = False,
    report_to = "none",
    optim = "paged_adamw_8bit",
)

# %%
trainer = Trainer(
    model = model,
    args = training_args,
    train_dataset = train_ds,
    eval_dataset = eval_ds
)

# %%
trainer.train()
# Out:
# {'id': ['ex10-14', 'ex10-51'], 'image_url': ['https://images.pokemontcg.io/ex10/14_hires.png', 'https://images.pokemontcg.io/ex10/51_hires.png'], 'caption': ["A Stage 1 Pokemon Card of type Psychic with the title Slowking and 70 HP of rarity Rare Holo evolved from Slowpoke from the set Unseen Forces.  It has the attack Aftermath with the cost Psychic, Colorless, the energy cost 2 and the damage of 20+ with the description: Does 20 damage plus 10 more damage for each Pokemon Tool card in your discard pile. You can't add more than 60 damage in this way. It has the ability Item Search with the description: Once during your turn (before your attack), you may search your deck for a Pokemon Tool card, show it to your opponent, and put it into your hand. Shuffle your deck afterward. This power can't be used if Slowking is affected by a Special Condition. It has weakness against Grass 2. ", 'A Basic Pokemon Card of type Grass with the title Chikorita and 50 HP of rarity Common from the set Unseen Forces.  It has the attack Headbutt with the cost Colorless, the energy cost 1 and the damage of 10. It has the attack Razor Leaf with the cost Grass, Colorless, the energy cost 2 and the damage of 20. It has weakness against Fire 2. It has resistance against Water -30. '], 'name': ['Slowking', 'Chikorita'], 'hp': [70, 50], 'set_name': ['Unseen Forces', 'Unseen Forces']}
# {'id': ['swsh11-62', 'xy1-3'], 'image_url': ['https://images.pokemontcg.io/swsh11/62_hires.png', 'https://images.pokemontcg.io/xy1/3_hires.png'], 'caption': ["A Basic Pokemon Card of type Psychic with the title Clefairy and 60 HP of rarity Common from the set Lost Origin and the flavor text: It can be found in quiet mountain areas on a full moon's night. Its dancing and its tiny, faintly glowing wings confer upon it anlovely fairylike quality. It has the attack Wonder Storm with the cost Colorless, Colorless, Colorless, the energy cost 3 and the damage of 20 with the description: This attack does 20 damage for each Psychic Energy attached to all of your Pokemon. It has the ability Moon-Watching Party with the description: Once during your turn, if this Pokemon is in the Active Spot, for each of your Benched Clefairy, you may search your deck for a Psychic Energy card and attach it to that Clefairy. Then, shuffle your deck. It has weakness against Metal 2. ", "A Basic Pokemon Card of type Grass with the title Weedle and 50 HP of rarity Common from the set XY and the flavor text: Often found in forests and grasslands. It has a sharp, toxic barb of around two inches on top of its head. It has the attack Leaf Munch with the cost Grass, the energy cost 1 and the damage of 10+ with the description: If your opponent's Active Pokemon is a Grass Pokemon, this attack does 20 more damage. It has weakness against Fire 2. "], 'name': ['Clefairy', 'Weedle'], 'hp': [60, 50], 'set_name': ['Lost Origin', 'XY']}
# {'id': ['pl3-56', 'swsh12-67'], 'image_url': ['https://images.pokemontcg.io/pl3/56_hires.png', 'https://images.pokemontcg.io/swsh12/67_hires.png'], 'caption': ["A Basic, SP Pokemon Card of type Colorless with the title Dragonite FB and 100 HP of rarity Uncommon from the set Supreme Victors.  It has the attack Mach Blow with the cost Colorless, Colorless, Colorless, the energy cost 3 and the damage of 20 with the description: If the Defending Pokemon is a Pokemon SP, this attack's base damage is 80 instead of 20. It has the attack Giant Tail with the cost Colorless, Colorless, Colorless, Colorless, the energy cost 4 and the damage of 100 with the description: Flip a coin. If tails, this attack does nothing. It has weakness against Colorless 2. It has resistance against Fighting -20. ", "A Basic Pokemon Card of type Psychic with the title Ralts and 60 HP of rarity Common from the set Silver Tempest and the flavor text: It is highly attuned to the emotions of people and Pokemon. It hides if it senses hostility. It has the attack Memory Skip with the cost Psychic, the energy cost 1 and the damage of 10 with the description: Choose 1 of your opponent's Active Pokemon's attacks. During your opponent's next turn, that Pokemon can't use that attack. It has weakness against Metal 2. "], 'name': ['Dragonite FB', 'Ralts'], 'hp': [100, 60], 'set_name': ['Supreme Victors', 'Silver Tempest']}
# {'id': ['hgss2-47', 'neo1-35'], 'image_url': ['https://images.pokemontcg.io/hgss2/47_hires.png', 'https://images.pokemontcg.io/neo1/35_hires.png'], 'caption': ['A Basic Pokemon Card of type Grass with the title Cherubi and 50 HP of rarity Common from the set HSUnleashed and the flavor text: It evolves by sucking the energy out of the small ball where it had been storing nutrients. It has the attack Tackle with the cost Colorless, the energy cost 1 and the damage of 10. It has weakness against Fire 2. It has resistance against Water -20. ', 'A Stage 1 Pokemon Card of type Colorless with the title Furret and 60 HP of rarity Uncommon evolved from Sentret from the set Neo Genesis and the flavor text: It makes a nest to suit its long and skinny body. The nest is impossible for other Pokemon to enter. It has the attack Quick Attack with the cost Colorless, Colorless, the energy cost 2 and the damage of 20+ with the description: Flip a coin. If heads, this attack does 20 damage plus 10 more damage; if tails, this attack does 20 damage. It has the attack Slam with the cost Colorless, Colorless, Colorless, the energy cost 3 and the damage of 30 with the description: Flip 2 coins. This attack does 30 damage times the number of heads. It has weakness against Fighting 2. It has resistance against Psychic -30. '], 'name': ['Cherubi', 'Furret'], 'hp': [50, 60], 'set_name': ['HS—Unleashed', 'Neo Genesis']}
# {'id': ['xy4-80', 'ex1-56'], 'image_url': ['https://images.pokemontcg.io/xy4/80_hires.png', 'https://images.pokemontcg.io/ex1/56_hires.png'], 'caption': ["A Basic Pokemon Card of type Colorless with the title Chansey and 100 HP of rarity Common from the set Phantom Forces and the flavor text: It is said to deliver happiness. Being compassionate, it shares its egg with injured people. It has the attack Nap with the cost Colorless, the energy cost 1 with the description: Heal 30 damage from this Pokemon. It has the attack Lucky Punch with the cost Colorless, Colorless, Colorless, the energy cost 3 and the damage of 100 with the description: If you don't have exactly 7 cards in your hand, this attack does nothing. It has weakness against Fighting 2. ", 'A Basic Pokemon Card of type Fighting with the title Makuhita and 50 HP of rarity Common from the set Ruby & Sapphire.  It has the attack Slap Push with the cost Colorless, the energy cost 1 and the damage of 10. It has the attack Lunge Out with the cost Colorless, Colorless, the energy cost 2 and the damage of 20. It has weakness against Psychic 2. '], 'name': ['Chansey', 'Makuhita'], 'hp': [100, 50], 'set_name': ['Phantom Forces', 'Ruby & Sapphire']}
# {'id': ['swsh10-35', 'sm8-59'], 'image_url': ['https://images.pokemontcg.io/swsh10/35_hires.png', 'https://images.pokemontcg.io/sm8/59_hires.png'], 'caption': ['A Basic Pokemon Card of type Water with the title Barboach and 60 HP of rarity Common from the set Astral Radiance and the flavor text: Makes its home in swamps with murky water. The poor visibility hides this Pokemon from predators, and the slime on its body makes grasping it difficult. It has the attack Rain Splash with the cost Water, Colorless, Colorless, the energy cost 3 and the damage of 40. It has weakness against Lightning 2. ', 'A Basic Pokemon Card of type Water with the title Suicune and 110 HP of rarity Rare Holo from the set Lost Thunder and the flavor text: Said to be the embodiment of north winds, it can instantly purify filthy, murky water. It has the attack Aurora Gain with the cost Water, Colorless, Colorless, the energy cost 3 and the damage of 70 with the description: Heal 30 damage from this Pokemon. It has the ability Frozen Flow with the description: Once during your turn (before your attack), if this Pokemon is your Active Pokemon, you may have your opponent switch their Active Pokemon with 1 of their Benched Pokemon. It has weakness against Grass 2. '], 'name': ['Barboach', 'Suicune'], 'hp': [60, 110], 'set_name': ['Astral Radiance', 'Lost Thunder']}
# {'id': ['ex11-33', 'ex16-102'], 'image_url': ['https://images.pokemontcg.io/ex11/33_hires.png', 'https://images.pokemontcg.io/ex16/102_hires.png'], 'caption': ["A Stage 1 Pokemon Card of type Grass with the title Weezing and 70 HP of rarity Rare evolved from Koffing from the set Delta Species.  It has the attack Mist Attack with the cost Grass, the energy cost 1 with the description: Does 10 damage to each of your opponent's Pokemon. (Don't apply Weakness and Resistance for Benched Pokemon.) It has the attack Sludge Whirlpool with the cost Grass, Colorless, Colorless, the energy cost 3 and the damage of 50. It has the ability Body Odor with the description: As long as Weezing is the Active Pokemon, put 1 counter on each of your opponent's Pokemon that has any Poke-Bodies between turns. It has weakness against Psychic 2. ", "A Basic, Star Pokemon Card of type Water with the title Vaporeon  and 70 HP of rarity Rare Holo Star from the set Power Keepers.  It has the attack Whirlpool with the cost Water, Water, Colorless, the energy cost 3 and the damage of 40 with the description: Flip a coin. If heads, discard an Energy card attached to the Defending Pokemon. It has the ability Blue Ray with the description: Once during your turn, when you put Vaporeon Star from your hand onto your Bench, you may remove all Special Conditions and 3 damage counters from each Active Pokemon (both yours and your opponent's). It has weakness against Lightning 2. "], 'name': ['Weezing', 'Vaporeon ★'], 'hp': [70, 70], 'set_name': ['Delta Species', 'Power Keepers']}
# {'id': ['ex15-46', 'mcd11-3'], 'image_url': ['https://images.pokemontcg.io/ex15/46_hires.png', 'https://images.pokemontcg.io/mcd11/3_hires.png'], 'caption': ['A Basic Pokemon Card of type Grass with the title Dratini  and 40 HP of rarity Common from the set Dragon Frontiers.  It has the attack Ram with the cost Colorless, the energy cost 1 and the damage of 10. ', "A Basic Pokemon Card of type Fire with the title Tepig and 70 HP of rarity None from the set McDonald's Collection 2011 and the flavor text: It blows fire through its nose. When it catches a cold, the fire becomes pitch-black smoke instead. It has the attack Ember with the cost Fire, Colorless, the energy cost 2 and the damage of 30 with the description: Discard an Energy attached to this Pokemon. It has weakness against Water 2. "], 'name': ['Dratini δ', 'Tepig'], 'hp': [40, 70], 'set_name': ['Dragon Frontiers', "McDonald's Collection 2011"]}
# {'id': ['xy7-46', 'smp-SM218'], 'image_url': ['https://images.pokemontcg.io/xy7/46_hires.png', 'https://images.pokemontcg.io/smp/SM218_hires.png'], 'caption': ["A Stage 1 Pokemon Card of type Darkness with the title Malamar and 90 HP of rarity Common evolved from Inkay from the set Ancient Origins and the flavor text: It lures prey close with hypnotic motions, then wraps its tentacles around it before finishing it off with digestive fluids. It has the attack Entangling Control with the cost Colorless, the energy cost 1 with the description: Switch 1 of your opponent's Benched Pokemon with his or her Active Pokemon. The new Active Pokemon is now Confused. It has the attack Trash Tentacle with the cost Darkness, the energy cost 1 and the damage of 30 with the description: Put a card from your discard pile into your hand. It has weakness against Fighting 2. It has resistance against Psychic -20. ", "A Basic Pokemon Card of type Grass with the title Buzzwole and 130 HP of rarity Promo from the set SM Black Star Promos and the flavor text: Although it's alien to this world and a danger here, it's apparently a common organism in the world where it normally lives. It has the attack Touchdown with the cost Grass, Colorless, the energy cost 2 and the damage of 60 with the description: Heal 30 damage from this Pokemon. It has the ability Beast Boost with the description: This Pokemon's attacks do 20 more damage to your opponent's Active Pokemon for each Prize card you have taken (before applying Weakness and Resistance). It has weakness against Fire 2. "], 'name': ['Malamar', 'Buzzwole'], 'hp': [90, 130], 'set_name': ['Ancient Origins', 'SM Black Star Promos']}
#     <div>
#
#       <progress value='25' max='25' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [25/25 08:29, Epoch 0/1]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Step</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>10</td>
#       <td>1.597500</td>
#       <td>1.175423</td>
#     </tr>
#     <tr>
#       <td>20</td>
#       <td>0.894900</td>
#       <td>0.887494</td>
#     </tr>
#   </tbody>
# </table><p>
# {'id': ['xy2-11', 'dp1-72'], 'image_url': ['https://images.pokemontcg.io/xy2/11_hires.png', 'https://images.pokemontcg.io/dp1/72_hires.png'], 'caption': ['A Basic, EX Pokemon Card of type Fire with the title Charizard-EX and 180 HP of rarity Rare Holo EX from the set Flashfire.  It has the attack Stoke with the cost Colorless, the energy cost 1 with the description: Flip a coin. If heads, search your deck for up to 3 basic Energy cards and attach them to this Pokemon. Shuffle your deck afterward. It has the attack Fire Blast with the cost Fire, Colorless, Colorless, Colorless, the energy cost 4 and the damage of 120 with the description: Discard an Energy attached to this Pokemon. It has weakness against Water 2. ', 'A Basic Pokemon Card of type Water with the title Buizel and 60 HP of rarity Common from the set Diamond & Pearl and the flavor text: It has a flotation sac that is like an inflatable collar. It floats on water with its head out. It has the attack Splash About with the cost Water, the energy cost 1 and the damage of 10+ with the description: If Buizel has less Energy attached to it than the Defending Pokemon, this attack does 10 damage plus 10 more damage. It has weakness against Lightning +10. '], 'name': ['Charizard-EX', 'Buizel'], 'hp': [180, 60], 'set_name': ['Flashfire', 'Diamond & Pearl']}
# {'id': ['bw2-59', 'swsh5-64'], 'image_url': ['https://images.pokemontcg.io/bw2/59_hires.png', 'https://images.pokemontcg.io/swsh5/64_hires.png'], 'caption': ["A Basic Pokemon Card of type Fighting with the title Sawk and 90 HP of rarity Uncommon from the set Emerging Powers and the flavor text: Tying their belts gets them pumped and makes their punches more destructive. Disturbing their training angers them. It has the attack Five Fierce Chops with the cost Fighting, Colorless, the energy cost 2 and the damage of 20 with the description: Flip 5 coins. This attack does 20 damage times the number of heads. This Pokemon can't attack during your next turn. It has weakness against Psychic 2. ", 'A Stage 1 Pokemon Card of type Psychic with the title Dottler and 70 HP of rarity Uncommon evolved from Blipbug from the set Battle Styles and the flavor text: As it grows inside its shell, it uses its psychic abilities to monitor the outside world and prepare for evolution. It has the attack Radar with the cost Psychic, the energy cost 1 with the description: Look at the top 4 cards of your deck and put them back in any order. It has the attack Ram with the cost Colorless, Colorless, the energy cost 2 and the damage of 20. It has weakness against Darkness 2. It has resistance against Fighting -30. '], 'name': ['Sawk', 'Dottler'], 'hp': [90, 70], 'set_name': ['Emerging Powers', 'Battle Styles']}
# {'id': ['swsh10-43', 'ex3-11'], 'image_url': ['https://images.pokemontcg.io/swsh10/43_hires.png', 'https://images.pokemontcg.io/ex3/11_hires.png'], 'caption': ['A Basic Pokemon Card of type Water with the title Hisuian Basculin and 50 HP of rarity Common from the set Astral Radiance and the flavor text: Though it differs from other Basculin in several respects, including demeanorthis one is gentleI have categorized it as a regional form given the vast array of shared qualities. It has the attack Gather the Crew with the cost the energy cost 0 with the description: Search your deck for up to 2 Basic Pokemon and put them onto your Bench. Then, shuffle your deck. It has the attack Tackle with the cost Water, the energy cost 1 and the damage of 10. It has weakness against Lightning 2. ', "A Stage 1 Pokemon Card of type Grass with the title Shedinja and 30 HP of rarity Rare Holo evolved from Nincada from the set Dragon.  It has the attack Damage Curse with the cost Colorless, the energy cost 1 with the description: Put 1 damage counter, plus 1 more damage counter for each damage counter on Shedinja, on the Defending Pokemon. It has the ability Wonder Guard with the description: Prevent all effects of attacks, including damage, done to Shedinja by your opponent's Evolved Pokemon and Pokemon-ex. "], 'name': ['Hisuian Basculin', 'Shedinja'], 'hp': [50, 30], 'set_name': ['Astral Radiance', 'Dragon']}
# {'id': ['swsh8-107', 'pop4-5'], 'image_url': ['https://images.pokemontcg.io/swsh8/107_hires.png', 'https://images.pokemontcg.io/pop4/5_hires.png'], 'caption': ["A Stage 1 Pokemon Card of type Lightning with the title Toxtricity and 130 HP of rarity Rare Holo evolved from Toxel from the set Fusion Strike and the flavor text: This short-tempered and aggressive Pokemon chugs stagnant water to absorb any toxins it might contain. It has the attack Punk Shock with the cost Lightning, Colorless, the energy cost 2 and the damage of 70 with the description: You may choose to make your opponent's Active Pokemon Paralyzed. If you do, this Pokemon also does 70 damage to itself. It has weakness against Fighting 2. ", "A Stage 2 Pokemon Card of type Grass with the title Sceptile and 100 HP of rarity Rare evolved from Grovyle from the set POP Series 4.  It has the attack Tail Rap with the cost Grass, Colorless, Colorless, the energy cost 3 and the damage of 50 with the description: Flip 2 coins. This attack does 50 damage times the number of heads. It has the ability Energy Trans with the description: As often as you like during your turn (before your attack), move a Grass Energy card attached to 1 of your Pokemon to another of your Pokemon. This power can't be used if Sceptile is affected by a Special Condition. It has weakness against Fire 2. It has resistance against Water -30. "], 'name': ['Toxtricity', 'Sceptile'], 'hp': [130, 100], 'set_name': ['Fusion Strike', 'POP Series 4']}
# {'id': ['swsh9-34', 'sm3-141'], 'image_url': ['https://images.pokemontcg.io/swsh9/34_hires.png', 'https://images.pokemontcg.io/sm3/141_hires.png'], 'caption': ["A Basic Pokemon Card of type Water with the title Snorunt and 60 HP of rarity Common from the set Brilliant Stars and the flavor text: It can only survive in cold areas. It bounces happily around, even in environments as cold as -150 degrees Fahrenheit. It has the attack Ice Breath with the cost Water, the energy cost 1 with the description: Flip a coin. If heads, your opponent's Active Pokemon is now Paralyzed. It has the attack Icy Snow with the cost Water, Colorless, the energy cost 2 and the damage of 20. It has weakness against Metal 2. ", "A Stage 1, GX Pokemon Card of type Dragon with the title Noivern-GX and 200 HP of rarity Rare Ultra evolved from Noibat from the set Burning Shadows.  It has the attack Distort with the cost Darkness, Colorless, the energy cost 2 and the damage of 50 with the description: Your opponent can't play any Item cards from their hand during their next turn. It has the attack Sonic Volume with the cost Psychic, Darkness, Colorless, the energy cost 3 and the damage of 120 with the description: Your opponent can't play any Special Energy cards from their hand during their next turn. It has the attack Boomburst-GX with the cost Psychic, Darkness, Colorless, the energy cost 3 with the description: This attack does 50 damage to each of your opponent's Pokemon. (Don't apply Weakness and Resistance for Benched Pokemon.) (You can't use more than 1 GX attack in a game.) It has weakness against Fairy 2. "], 'name': ['Snorunt', 'Noivern-GX'], 'hp': [60, 200], 'set_name': ['Brilliant Stars', 'Burning Shadows']}
# {'id': ['ecard3-118', 'bw9-90'], 'image_url': ['https://images.pokemontcg.io/ecard3/118_hires.png', 'https://images.pokemontcg.io/bw9/90_hires.png'], 'caption': ['A Basic Pokemon Card of type Grass with the title Zubat and 50 HP of rarity Common from the set Skyridge.  It has the attack Wing Attack with the cost Colorless, the energy cost 1 and the damage of 10. It has the attack Poison Spray with the cost Grass, Colorless, the energy cost 2 and the damage of 10 with the description: The Defending Pokemon is now Poisoned. It has weakness against Psychic 2. ', 'A Basic Pokemon Card of type Colorless with the title Eevee and 60 HP of rarity Common from the set Plasma Freeze and the flavor text: Thanks to its unstable genetic makeup, this special Pokemon conceals many different possible evolutions. It has the attack Signs of Evolution with the cost Colorless, the energy cost 1 with the description: Search your deck for 3 Pokemon of different types that evolve from Eevee. Reveal them and put them into your hand. Shuffle your deck afterward. It has the attack Bite with the cost Colorless, Colorless, Colorless, the energy cost 3 and the damage of 30. It has weakness against Fighting 2. '], 'name': ['Zubat', 'Eevee'], 'hp': [50, 60], 'set_name': ['Skyridge', 'Plasma Freeze']}
# {'id': ['xy5-57', 'pop6-15'], 'image_url': ['https://images.pokemontcg.io/xy5/57_hires.png', 'https://images.pokemontcg.io/pop6/15_hires.png'], 'caption': ['A Basic Pokemon Card of type Lightning with the title Chinchou and 70 HP of rarity Common from the set Primal Clash and the flavor text: It shoots positive and negative electricity between the tips of its two antennae and zaps its enemies. It has the attack Wave Splash with the cost Water, Colorless, the energy cost 2 and the damage of 20. It has weakness against Fighting 2. It has resistance against Metal -20. ', 'A Basic Pokemon Card of type Water with the title Piplup and 60 HP of rarity Common from the set POP Series 6 and the flavor text: Because it is very proud, it hates accepting food from people. Its thick down guards it from cold. It has the attack Peck with the cost the energy cost 0 and the damage of 10. It has the attack Water Spash with the cost Water, Colorless, the energy cost 2 and the damage of 20+ with the description: Flip a coin. If heads, this attack does 20 damage plus 10 more damage. It has weakness against Lightning +10. '], 'name': ['Chinchou', 'Piplup'], 'hp': [70, 60], 'set_name': ['Primal Clash', 'POP Series 6']}
# {'id': ['ex10-66', 'swsh1-143'], 'image_url': ['https://images.pokemontcg.io/ex10/66_hires.png', 'https://images.pokemontcg.io/swsh1/143_hires.png'], 'caption': ['A Basic Pokemon Card of type Grass with the title Pineco and 50 HP of rarity Common from the set Unseen Forces.  It has the attack Ram with the cost Colorless, the energy cost 1 and the damage of 10. It has weakness against Fire 2. ', 'A Basic Pokemon Card of type Colorless with the title Hoothoot and 70 HP of rarity Common from the set Sword & Shield and the flavor text: It begins to hoot at the same time every day. Some Trainers use them in place of clocks. It has the attack Send Back with the cost Colorless, the energy cost 1 with the description: Your opponent switches their Active Pokemon with 1 of their Benched Pokemon. It has the attack Wing Attack with the cost Colorless, Colorless, the energy cost 2 and the damage of 20. It has weakness against Lightning 2. It has resistance against Fighting -30. '], 'name': ['Pineco', 'Hoothoot'], 'hp': [50, 70], 'set_name': ['Unseen Forces', 'Sword & Shield']}
# {'id': ['swsh6-39', 'xy11-78'], 'image_url': ['https://images.pokemontcg.io/swsh6/39_hires.png', 'https://images.pokemontcg.io/xy11/78_hires.png'], 'caption': ["A Stage 2 Pokemon Card of type Water with the title Walrein and 170 HP of rarity Rare evolved from Sealeo from the set Chilling Reign and the flavor text: It shatters drift ice with its strong tusks. Its thick layer of blubber repels enemy attacks. It has the attack Aurora Beam with the cost Colorless, Colorless, the energy cost 2 and the damage of 70. It has the attack Hail Prison with the cost Water, Water, Colorless, the energy cost 3 and the damage of 160 with the description: Discard 2 Energy from this Pokemon. Your opponent's Active Pokemon is now Paralyzed. It has weakness against Metal 2. ", "A Basic, EX Pokemon Card of type Fairy with the title Gardevoir-EX and 170 HP of rarity Rare Holo EX from the set Steam Siege.  It has the attack Link Blast with the cost Fairy, Colorless, the energy cost 2 and the damage of 30+ with the description: If this Pokemon and your opponent's Active Pokemon have the same amount of Energy attached to them, this attack does 70 more damage. It has the attack Luminous Blade with the cost Fairy, Fairy, Colorless, the energy cost 3 and the damage of 120 with the description: Discard an Energy attached to this Pokemon. It has weakness against Metal 2. It has resistance against Darkness -20. "], 'name': ['Walrein', 'Gardevoir-EX'], 'hp': [170, 170], 'set_name': ['Chilling Reign', 'Steam Siege']}
# {'id': ['ecard2-49', 'swsh5-67'], 'image_url': ['https://images.pokemontcg.io/ecard2/49_hires.png', 'https://images.pokemontcg.io/swsh5/67_hires.png'], 'caption': ["A Stage 1 Pokemon Card of type Grass with the title Gloom and 70 HP of rarity Uncommon evolved from Oddish from the set Aquapolis.  It has the attack Sleep Sap with the cost Colorless, Colorless, the energy cost 2 and the damage of 20 with the description: Both the Defending Pokemon and Gloom are now Asleep (after doing damage). It has the ability Enervating Pollen with the description: As long as Gloom is in play, Resistance on each player's Active Pokemon only reduces damage by 10. It has weakness against Fire 2. ", "A Stage 1, Single Strike Pokemon Card of type Fighting with the title Primeape and 120 HP of rarity Rare evolved from Mankey from the set Battle Styles and the flavor text: The blood vessels in its brain are sturdier than those of other Pokemon, so it can stay healthy despite its constant raging. It has the attack Field Crush with the cost Colorless, the energy cost 1 and the damage of 20 with the description: If your opponent has a Stadium in play, discard it. It has the attack Steamin' Mad Strike with the cost Fighting, Fighting, the energy cost 2 and the damage of 50 with the description: This attack does 50 damage for each of your Benched Pokemon that has any damage counters on it. It has weakness against Psychic 2. "], 'name': ['Gloom', 'Primeape'], 'hp': [70, 120], 'set_name': ['Aquapolis', 'Battle Styles']}
# {'id': ['ex10-73', 'cel25-19'], 'image_url': ['https://images.pokemontcg.io/ex10/73_hires.png', 'https://images.pokemontcg.io/cel25/19_hires.png'], 'caption': ['A Basic Pokemon Card of type Fire with the title Slugma and 40 HP of rarity Common from the set Unseen Forces.  It has the attack Yawn with the cost Colorless, the energy cost 1 with the description: The Defending Pokemon is now Asleep. It has the attack Headbutt with the cost Colorless, the energy cost 1 and the damage of 10. It has weakness against Water 2. ', "A Basic Pokemon Card of type Darkness with the title Yveltal and 120 HP of rarity Rare from the set Celebrations.  It has the attack Cry of Destruction with the cost Colorless, Colorless, the energy cost 2 with the description: Discard up to 3 Special Energy from your opponent's Pokemon. It has the attack Dark Feather with the cost Darkness, Colorless, Colorless, the energy cost 3 and the damage of 100. It has weakness against Lightning 2. It has resistance against Fighting -30. "], 'name': ['Slugma', 'Yveltal'], 'hp': [40, 120], 'set_name': ['Unseen Forces', 'Celebrations']}
# {'id': ['bw3-44', 'sm8-151'], 'image_url': ['https://images.pokemontcg.io/bw3/44_hires.png', 'https://images.pokemontcg.io/sm8/151_hires.png'], 'caption': ['A Basic Pokemon Card of type Psychic with the title Yamask and 60 HP of rarity Common from the set Noble Victories and the flavor text: Each of them carries a mask that used to be its face when it was human. Sometimes they look at it and cry. It has the attack Perplex with the cost Psychic, the energy cost 1 and the damage of 10 with the description: Flip a coin. If heads, the Defending Pokemon is now Confused. It has weakness against Darkness 2. ', "A Basic Pokemon Card of type Fairy with the title Tapu Fini and 120 HP of rarity Rare Holo from the set Lost Thunder and the flavor text: The guardian deity of Poni, it can control water. People say it can create pure water that will wash away any uncleanness. It has the attack Dream Away with the cost Fairy, Colorless, the energy cost 2 with the description: Flip a coin. If heads, your opponent shuffles their Active Pokemon and all cards attached to it into their deck. It has the attack Wonder Shine with the cost Fairy, Fairy, Colorless, the energy cost 3 and the damage of 100 with the description: Your opponent's Active Pokemon is now Confused. It has weakness against Metal 2. It has resistance against Darkness -20. "], 'name': ['Yamask', 'Tapu Fini'], 'hp': [60, 120], 'set_name': ['Noble Victories', 'Lost Thunder']}
# {'id': ['ex8-19', 'xy6-73'], 'image_url': ['https://images.pokemontcg.io/ex8/19_hires.png', 'https://images.pokemontcg.io/xy6/73_hires.png'], 'caption': ["A Stage 2 Pokemon Card of type Water with the title Ludicolo and 100 HP of rarity Rare evolved from Lombre from the set Deoxys.  It has the attack Water Punch with the cost Colorless, Colorless, Colorless, the energy cost 3 and the damage of 40+ with the description: Flip a coin for each Water Energy attached to Ludicolo. This attack does 40 damage plus 20 more damage for each heads. It has the ability Happy Dance with the description: Once during your turn (before your attack), you may remove 1 damage counter from each of your Pokemon. You can't use more than 1 Happy Dance Poke-Power each turn. This power can't be used if Ludicolo is affected by a Special Condition. It has weakness against Lightning 2. ", 'A Basic Pokemon Card of type Colorless with the title Swablu and 40 HP of rarity Common from the set Roaring Skies and the flavor text: It constantly grooms its cotton-like wings. It takes a shower to clean itself if it becomes dirty. It has the attack Bind Wound with the cost Colorless, the energy cost 1 with the description: Heal 20 damage from 1 of your Pokemon. It has weakness against Lightning 2. It has resistance against Fighting -20. '], 'name': ['Ludicolo', 'Swablu'], 'hp': [100, 40], 'set_name': ['Deoxys', 'Roaring Skies']}
# {'id': ['swsh8-63', 'swsh8-55'], 'image_url': ['https://images.pokemontcg.io/swsh8/63_hires.png', 'https://images.pokemontcg.io/swsh8/55_hires.png'], 'caption': ['A Stage 1 Pokemon Card of type Water with the title Marshtomp and 90 HP of rarity Uncommon evolved from Mudkip from the set Fusion Strike and the flavor text: Living on muddy ground that provides poor footing has made its legs sturdy. It has the attack Mud-Slap with the cost Colorless, Colorless, the energy cost 2 and the damage of 30. It has the attack Energy Loop with the cost Water, Colorless, Colorless, the energy cost 3 and the damage of 80 with the description: Put an Energy attached to this Pokemon into your hand. It has weakness against Lightning 2. ', 'A Basic Pokemon Card of type Water with the title Totodile and 70 HP of rarity Common from the set Fusion Strike and the flavor text: Its powerful, well-developed jaws are capable of crushing anything. Even its Trainer must be careful. It has the attack Rain Splash with the cost Water, the energy cost 1 and the damage of 20. It has weakness against Lightning 2. '], 'name': ['Marshtomp', 'Totodile'], 'hp': [90, 70], 'set_name': ['Fusion Strike', 'Fusion Strike']}
# {'id': ['swsh7-114', 'swsh1-197'], 'image_url': ['https://images.pokemontcg.io/swsh7/114_hires.png', 'https://images.pokemontcg.io/swsh1/197_hires.png'], 'caption': ['A Stage 1 Pokemon Card of type Dragon with the title Zweilous and 100 HP of rarity Uncommon evolved from Deino from the set Evolving Skies and the flavor text: Their two heads will fight each other over a single piece of food. Zweilous are covered in scars even without battling others. It has the attack Bite with the cost Psychic, Darkness, the energy cost 2 and the damage of 40. It has the attack Dragon Headbutt with the cost Psychic, Darkness, Colorless, Colorless, the energy cost 4 and the damage of 100. ', "A Basic, V Pokemon Card of type Colorless with the title Snorlax V and 220 HP of rarity Rare Ultra from the set Sword & Shield.  It has the attack Swallow with the cost Colorless, Colorless, Colorless, the energy cost 3 and the damage of 60 with the description: Heal from this Pokemon the same amount of damage you did to your opponent's Active Pokemon. It has the attack Falling Down with the cost Colorless, Colorless, Colorless, Colorless, the energy cost 4 and the damage of 170 with the description: This Pokemon is now Asleep. It has weakness against Fighting 2. "], 'name': ['Zweilous', 'Snorlax V'], 'hp': [100, 220], 'set_name': ['Evolving Skies', 'Sword & Shield']}
# {'id': ['swsh4-109', 'swsh8-168'], 'image_url': ['https://images.pokemontcg.io/swsh4/109_hires.png', 'https://images.pokemontcg.io/swsh8/168_hires.png'], 'caption': ["A Stage 2 Pokemon Card of type Darkness with the title Krookodile and 150 HP of rarity Rare evolved from Krokorok from the set Vivid Voltage and the flavor text: It conceals itself in sandstorms that Flygon whip up and waits patiently for prey to appear. It has the attack Dredge Up with the cost Colorless, Colorless, the energy cost 2 with the description: Discard the top 3 cards of your opponent's deck. It has the attack Tantrum with the cost Darkness, Colorless, Colorless, Colorless, the energy cost 4 and the damage of 180 with the description: This Pokemon is now Confused. It has weakness against Grass 2. ", "A Basic Pokemon Card of type Darkness with the title Trubbish and 70 HP of rarity Common from the set Fusion Strike and the flavor text: This Pokemon was born from a bag stuffed with trash. Galarian Weezing relish the fumes belched by Trubbish. It has the attack Call for Family with the cost Darkness, the energy cost 1 with the description: Search your deck for a Basic Pokemon and put it onto your Bench. Then, shuffle your deck. It has the attack Super Poison Breath with the cost Darkness, Colorless, the energy cost 2 and the damage of 20 with the description: Your opponent's Active Pokemon is now Poisoned. It has weakness against Fighting 2. "], 'name': ['Krookodile', 'Trubbish'], 'hp': [150, 70], 'set_name': ['Vivid Voltage', 'Fusion Strike']}
# {'id': ['sm10-161', 'sm8-73'], 'image_url': ['https://images.pokemontcg.io/sm10/161_hires.png', 'https://images.pokemontcg.io/sm8/73_hires.png'], 'caption': ["A Basic Pokemon Card of type Colorless with the title Happiny and 60 HP of rarity Uncommon from the set Unbroken Bonds and the flavor text: Usually it's a well-behaved Pokemon, but if you take its round rock away, it will cry and fuss and throw a big old tantrum. It has the ability Playhouse Heal with the description: Once during your turn (before your attack), you may flip a coin. If heads, heal 60 damage from 1 of your Pokemon. If you use this Ability, your turn ends. ", "A Basic Pokemon Card of type Lightning with the title Chinchou and 60 HP of rarity Common from the set Lost Thunder and the flavor text: It lives in the depths beyond the reach of sunlight. It flashes lights on its antennae to communicate with others of its kind. It has the attack Thunder Wave with the cost Colorless, the energy cost 1 with the description: Flip a coin. If heads, your opponent's Active Pokemon is now Paralyzed. It has the attack Lightning Ball with the cost Lightning, Colorless, the energy cost 2 and the damage of 20. It has weakness against Fighting 2. It has resistance against Metal -20. "], 'name': ['Happiny', 'Chinchou'], 'hp': [60, 60], 'set_name': ['Unbroken Bonds', 'Lost Thunder']}
# {'id': ['swsh4-5', 'hgss4-17'], 'image_url': ['https://images.pokemontcg.io/swsh4/5_hires.png', 'https://images.pokemontcg.io/hgss4/17_hires.png'], 'caption': ["A Stage 1 Pokemon Card of type Grass with the title Exeggutor and 140 HP of rarity Rare evolved from Exeggcute from the set Vivid Voltage and the flavor text: Each of its three heads has its own thoughts. When they want to go in different directions, Exeggutor becomes unable to move. It has the attack Head Crack with the cost Grass, the energy cost 1 and the damage of 30 with the description: Choose 1 of your opponent's Active Pokemon's attacks. During your opponent's next turn, that Pokemon can't use that attack. It has the attack Solar Beam with the cost Grass, Colorless, Colorless, the energy cost 3 and the damage of 90. It has weakness against Fire 2. ", "A Basic Pokemon Card of type Colorless with the title Ditto and 40 HP of rarity Rare from the set HSTriumphant and the flavor text: Its transformation ability is perfect. However, if made to laugh, it can't maintain its disguise. It has the attack Sharp Point with the cost Colorless, Colorless, the energy cost 2 and the damage of 20. It has the ability Dittobolic with the description: The number of Benched Pokemon your opponent can have is now 4. If your opponent has 5 Benched Pokemon, your opponent must discard 1 of them and all cards attached to it. It has weakness against Fighting 2. "], 'name': ['Exeggutor', 'Ditto'], 'hp': [140, 40], 'set_name': ['Vivid Voltage', 'HS—Triumphant']}
# {'id': ['sm1-112', 'ex9-41'], 'image_url': ['https://images.pokemontcg.io/sm1/112_hires.png', 'https://images.pokemontcg.io/ex9/41_hires.png'], 'caption': ["A Stage 1 Pokemon Card of type Colorless with the title Bewear and 130 HP of rarity Rare evolved from Stufful from the set Sun & Moon and the flavor text: This immensely dangerous Pokemon possesses overwhelming physical strength. Its habitat is generally off-limits. It has the attack Bear Hug with the cost Colorless, Colorless, the energy cost 2 and the damage of 40 with the description: The Defending Pokemon can't retreat during your opponent's next turn. It has the attack Superpower with the cost Colorless, Colorless, Colorless, the energy cost 3 and the damage of 80+ with the description: You may do 40 more damage. If you do, this Pokemon does 20 damage to itself. It has weakness against Fighting 2. ", "A Stage 1 Pokemon Card of type Colorless with the title Swellow and 70 HP of rarity Uncommon evolved from Taillow from the set Emerald.  It has the attack Peck with the cost Colorless, the energy cost 1 and the damage of 20. It has the attack Skill Dive with the cost Colorless, Colorless, Colorless, the energy cost 3 with the description: Choose 1 of your opponent's Pokemon. This attack does 40 damage to that Pokemon. (Don't apply Weakness and Resistance for Benched Pokemon.) It has weakness against Lightning 2. It has resistance against Fighting -30. "], 'name': ['Bewear', 'Swellow'], 'hp': [130, 70], 'set_name': ['Sun & Moon', 'Emerald']}
# {'id': ['sm75-8', 'swsh11-57'], 'image_url': ['https://images.pokemontcg.io/sm75/8_hires.png', 'https://images.pokemontcg.io/swsh11/57_hires.png'], 'caption': ['A Basic Pokemon Card of type Fire with the title Darumaka and 70 HP of rarity Common from the set Dragon Majesty and the flavor text: When it sleeps, it pulls its limbs into its body and its internal fire goes down to 1,100 degrees Fahrenheit. It has the attack Damage Rush with the cost Colorless, Colorless, the energy cost 2 and the damage of 10+ with the description: Flip a coin until you get tails. This attack does 30 more damage for each heads. It has weakness against Water 2. ', "A VSTAR Pokemon Card of type Lightning with the title Magnezone VSTAR and 270 HP of rarity Rare Holo VSTAR evolved from Magnezone V from the set Lost Origin.  It has the attack Magnetic Grip with the cost Lightning, Colorless, Colorless, the energy cost 3 and the damage of 180 with the description: Search your deck for up to 2 Item cards, reveal them, and put them into your hand. Then, shuffle your deck. It has the attack Electro Star with the cost Lightning, Lightning, the energy cost 2 with the description: This attack does 90 damage to 2 of your opponent's Benched Pokemon. (Don't apply Weakness and Resistance for Benched Pokemon.) (You can't use more than 1 VSTAR Power in a game.) It has weakness against Fighting 2. "], 'name': ['Darumaka', 'Magnezone VSTAR'], 'hp': [70, 270], 'set_name': ['Dragon Majesty', 'Lost Origin']}
# {'id': ['sm2-23', 'sm11-229'], 'image_url': ['https://images.pokemontcg.io/sm2/23_hires.png', 'https://images.pokemontcg.io/sm11/229_hires.png'], 'caption': ["A Basic Pokemon Card of type Water with the title Tentacool and 60 HP of rarity Common from the set Guardians Rising and the flavor text: They can be found lying dehydrated on beaches, but they are often still alive. When soaked in water, they will revive. It has the attack Sludge Shock with the cost Colorless, the energy cost 1 and the damage of 10 with the description: The Defending Pokemon can't be healed during your opponent's next turn. It has weakness against Grass 2. ", "A Stage 2, GX Pokemon Card of type Dragon with the title Dragonite-GX and 250 HP of rarity Rare Ultra evolved from Dragonair from the set Unified Minds.  It has the attack Dragon Claw with the cost Water, Lightning, Colorless, the energy cost 3 and the damage of 130. It has the attack Sky Judgment with the cost Colorless, Colorless, Colorless, Colorless, Colorless, the energy cost 5 and the damage of 270 with the description: Discard 3 Energy from this Pokemon. It has the attack Mach Delivery-GX with the cost Colorless, the energy cost 1 with the description: You may discard any number of cards from your hand until you have 9 or fewer. Draw cards until you have 10 cards in your hand. (You can't use more than 1 GX attack in a game.) It has weakness against Fairy 2. "], 'name': ['Tentacool', 'Dragonite-GX'], 'hp': [60, 250], 'set_name': ['Guardians Rising', 'Unified Minds']}
# {'id': ['swshp-SWSH179', 'hgss1-108'], 'image_url': ['https://images.pokemontcg.io/swshp/SWSH179_hires.png', 'https://images.pokemontcg.io/hgss1/108_hires.png'], 'caption': ["A Basic, V, Single Strike Pokemon Card of type Fire with the title Flareon V and 210 HP of rarity Promo from the set SWSH Black Star Promos.  It has the attack Flaming Breath with the cost Colorless, the energy cost 1 and the damage of 20 with the description: Search your deck for a Fire Energy card and attach it to this Pokemon. Then, shuffle your deck. It has the attack Scorching Column with the cost Fire, Fire, Colorless, the energy cost 3 and the damage of 120 with the description: Your opponent's Active Pokemon is now Burned. It has weakness against Water 2. ", "A Stage 2, Prime Pokemon Card of type Water with the title Feraligatr and 140 HP of rarity Rare Prime evolved from Croconaw from the set HeartGold & SoulSilver.  It has the attack Hydro Crunch with the cost Water, Water, Water, Water, the energy cost 4 and the damage of 60+ with the description: Does 60 damage plus 10 more damage for each damage counter on the Defending Pokemon. It has the ability Rain Dance with the description: As often as you like during your turn (before your attack), you may attach a Water Energy card from your hand to 1 of your Water Pokemon. This power can't be used if Feraligatr is affected by a Special Condition. It has weakness against Grass 2. "], 'name': ['Flareon V', 'Feraligatr'], 'hp': [210, 140], 'set_name': ['SWSH Black Star Promos', 'HeartGold & SoulSilver']}
# {'id': ['neo1-15', 'ex12-52'], 'image_url': ['https://images.pokemontcg.io/neo1/15_hires.png', 'https://images.pokemontcg.io/ex12/52_hires.png'], 'caption': ['A Stage 1 Pokemon Card of type Metal with the title Steelix and 110 HP of rarity Rare Holo evolved from Onix from the set Neo Genesis and the flavor text: Its body has been compressed deep under the ground. As a result, it is even harder than a diamond. It has the attack Tackle with the cost Colorless, Colorless, the energy cost 2 and the damage of 20. It has the attack Tail Crush with the cost Metal, Colorless, Colorless, the energy cost 3 and the damage of 30+ with the description: Flip a coin. If heads, this attack does 30 damage plus 20 more damage; if tails, this attack does 30 damage. It has weakness against Fire 2. It has resistance against Grass -30. ', 'A Basic Pokemon Card of type Psychic with the title Gastly and 40 HP of rarity Common from the set Legend Maker.  It has the attack Lick with the cost Colorless, the energy cost 1 with the description: Flip a coin. If heads, the Defending Pokemon is now Paralyzed. It has the attack Smog with the cost Psychic, the energy cost 1 with the description: The Defending Pokemon is now Poisoned. It has weakness against Darkness 2. It has resistance against Fighting -30. '], 'name': ['Steelix', 'Gastly'], 'hp': [110, 40], 'set_name': ['Neo Genesis', 'Legend Maker']}
# {'id': ['sm10-65', 'sm5-10'], 'image_url': ['https://images.pokemontcg.io/sm10/65_hires.png', 'https://images.pokemontcg.io/sm5/10_hires.png'], 'caption': ["A Stage 1 Pokemon Card of type Psychic with the title Golbat and 80 HP of rarity Uncommon evolved from Zubat from the set Unbroken Bonds and the flavor text: Every once in a while, you'll see a Golbat that's missing some fangs. This happens when hunger drives it to try biting a Steel-type Pokemon. It has the attack Bite with the cost Psychic, the energy cost 1 and the damage of 20. It has the attack Leech Life with the cost Colorless, Colorless, Colorless, the energy cost 3 and the damage of 40 with the description: Heal from this Pokemon the same amount of damage you did to your opponent's Active Pokemon. It has weakness against Lightning 2. It has resistance against Fighting -20. ", 'A Basic Pokemon Card of type Grass with the title Cherubi and 50 HP of rarity Common from the set Ultra Prism and the flavor text: It evolves by sucking the energy out of the small ball where it had been storing nutrients. It has the attack Surprise Attack with the cost Grass, the energy cost 1 and the damage of 30 with the description: Flip a coin. If tails, this attack does nothing. It has weakness against Fire 2. '], 'name': ['Golbat', 'Cherubi'], 'hp': [80, 50], 'set_name': ['Unbroken Bonds', 'Ultra Prism']}
# ...
# {'id': ['ex8-10', 'xy1-6'], 'image_url': ['https://images.pokemontcg.io/ex8/10_hires.png', 'https://images.pokemontcg.io/xy1/6_hires.png'], 'caption': ["A Stage 2 Pokemon Card of type Water with the title Ludicolo and 100 HP of rarity Rare Holo evolved from Lombre from the set Deoxys.  It has the attack Healing Steps with the cost Water, the energy cost 1 and the damage of 30 with the description: You may discard as many cards as you like from your hand. If you do, remove that many damage counters from Ludicolo. It has the attack Circular Steps with the cost Water, Colorless, Colorless, the energy cost 3 and the damage of 10 with the description: Does 10 damage times the number of Pokemon in play (both yours and your opponent's), excluding Ludicolo. It has the ability Swing Dance with the description: Once during your turn (before your attack), you may draw a card. This power can't be used if Ludicolo is affected by a Special Condition. It has weakness against Lightning 2. ", 'A Basic Pokemon Card of type Grass with the title Ledyba and 60 HP of rarity Common from the set XY and the flavor text: When the weather turns cold, lots of Ledyba gather from everywhere to cluster and keep each other warm. It has the attack Spinning Attack with the cost Grass, Grass, the energy cost 2 and the damage of 30. It has weakness against Fire 2. '], 'name': ['Ludicolo', 'Ledyba'], 'hp': [100, 60], 'set_name': ['Deoxys', 'XY']}
# {'id': ['sma-SV72', 'ex14-69'], 'image_url': ['https://images.pokemontcg.io/sma/SV72_hires.png', 'https://images.pokemontcg.io/ex14/69_hires.png'], 'caption': ["A Stage 1, GX Pokemon Card of type Metal with the title Scizor-GX and 210 HP of rarity Rare Shiny GX evolved from Scyther from the set Shiny Vault.  It has the attack Steel Wing with the cost Metal, Colorless, the energy cost 2 and the damage of 80 with the description: During your opponent's next turn, this Pokemon takes 30 less damage from attacks (after applying Weakness and Resistance). It has the attack Cross-Cut-GX with the cost Colorless, Colorless, Colorless, the energy cost 3 and the damage of 100+ with the description: If your opponent's Active Pokemon is an Evolution Pokemon, this attack does 100 more damage. (You can't use more than 1 GX attack in a game.) It has the ability Danger Perception with the description: If this Pokemon's remaining HP is 100 or less, its attacks do 80 more damage to your opponent's Active Pokemon (before applying Weakness and Resistance). It has weakness against Fire 2. It has resistance against Psychic -20. ", 'A Basic Pokemon Card of type Colorless with the title Whismur and 50 HP of rarity Common from the set Crystal Guardians.  It has the attack Supersonic with the cost Colorless, the energy cost 1 with the description: Flip a coin. If heads, the Defending Pokemon is now Confused. It has the attack Hyper Voice with the cost Colorless, Colorless, Colorless, the energy cost 3 and the damage of 30. It has weakness against Fighting 2. '], 'name': ['Scizor-GX', 'Whismur'], 'hp': [210, 50], 'set_name': ['Shiny Vault', 'Crystal Guardians']}
# {'id': ['sm75-44', 'pl2-26'], 'image_url': ['https://images.pokemontcg.io/sm75/44_hires.png', 'https://images.pokemontcg.io/pl2/26_hires.png'], 'caption': ["A Stage 2, GX Pokemon Card of type Dragon with the title Salamence-GX and 250 HP of rarity Rare Holo GX evolved from Shelgon from the set Dragon Majesty.  It has the attack Bright Flame with the cost Fire, Water, Colorless, Colorless, the energy cost 4 and the damage of 200 with the description: Discard 2 Energy from this Pokemon. It has the attack Flame Jet-GX with the cost Fire, Colorless, Colorless, the energy cost 3 with the description: This attack does 120 damage to 1 of your opponent's Pokemon. (Don't apply Weakness and Resistance for Benched Pokemon.) (You can't use more than 1 GX attack in a game.) It has the ability Dragon Lift with the description: Your Pokemon in play have no Retreat Cost, except Pokemon-GX and Pokemon-EX. It has weakness against Fairy 2. ", "A Stage 1 Pokemon Card of type Lightning with the title Jolteon and 80 HP of rarity Rare evolved from Eevee from the set Rising Rivals.  It has the attack Quick Attack with the cost Colorless, the energy cost 1 and the damage of 10+ with the description: Flip a coin. If heads, this attack does 10 damage plus 30 more damage. It has the attack Evolving Thunder with the cost Lightning, Colorless, the energy cost 2 and the damage of 50 with the description: If Jolteon evolved from Eevee during this turn, this attack does 10 damage to each of your opponent's Benched Pokemon. (Don't apply Weakness and Resistance for Benched Pokemon). It has the ability Undevelop with the description: Once during your turn (before your attack), you may devolve Jolteon and put Jolteon into your hand. This power can't be used if Jolteon is affected by a Special Condition. It has weakness against Fighting +20. It has resistance against Metal -20. "], 'name': ['Salamence-GX', 'Jolteon'], 'hp': [250, 80], 'set_name': ['Dragon Majesty', 'Rising Rivals']}
# {'id': ['ex1-59', 'hgss2-26'], 'image_url': ['https://images.pokemontcg.io/ex1/59_hires.png', 'https://images.pokemontcg.io/hgss2/26_hires.png'], 'caption': ['A Basic Pokemon Card of type Water with the title Mudkip and 50 HP of rarity Common from the set Ruby & Sapphire.  It has the attack Bubble with the cost Water, the energy cost 1 and the damage of 10 with the description: Flip a coin. If heads, the Defending Pokemon is now Paralyzed. It has weakness against Lightning 2. ', 'A Stage 2 Pokemon Card of type Darkness with the title Tyranitar and 140 HP of rarity Rare evolved from Pupitar from the set HSUnleashed and the flavor text: Extremely strong, it can change the landscape. It has an insolent nature that makes it not care about others. It has the attack Tail Crush with the cost Colorless, Colorless, Colorless, the energy cost 3 and the damage of 40+ with the description: Flip a coin. If heads, this attack does 40 damage plus 20 more damage. It has the attack Hyper Beam with the cost Darkness, Darkness, Colorless, Colorless, the energy cost 4 and the damage of 80 with the description: Discard an Energy card attached to the Defending Pokemon. It has weakness against Fighting 2. It has resistance against Psychic -20. '], 'name': ['Mudkip', 'Tyranitar'], 'hp': [50, 140], 'set_name': ['Ruby & Sapphire', 'HS—Unleashed']}
# {'id': ['ecard1-22', 'swshp-SWSH057'], 'image_url': ['https://images.pokemontcg.io/ecard1/22_hires.png', 'https://images.pokemontcg.io/swshp/SWSH057_hires.png'], 'caption': ['A Baby Pokemon Card of type Lightning with the title Pichu and 30 HP of rarity Rare Holo evolved from Pikachu from the set Expedition Base Set.  It has the attack Energy Patch with the cost Lightning, the energy cost 1 with the description: Take a basic Energy card attached to 1 of your Pokemon and attach it to another of your Pokemon. ', 'A Basic, V Pokemon Card of type Darkness with the title Grimmsnarl V and 220 HP of rarity Promo from the set SWSH Black Star Promos.  It has the attack Bite with the cost Darkness, the energy cost 1 and the damage of 40. It has the attack Spiky Knuckle with the cost Darkness, Darkness, Darkness, the energy cost 3 and the damage of 200 with the description: Put 2 Darkness Energy attached to this Pokemon into your hand. It has weakness against Grass 2. '], 'name': ['Pichu', 'Grimmsnarl V'], 'hp': [30, 220], 'set_name': ['Expedition Base Set', 'SWSH Black Star Promos']}
# {'id': ['bw4-51', 'swsh2-5'], 'image_url': ['https://images.pokemontcg.io/bw4/51_hires.png', 'https://images.pokemontcg.io/swsh2/5_hires.png'], 'caption': ['A Basic, EX Pokemon Card of type Lightning with the title Zekrom-EX and 180 HP of rarity Rare Holo EX from the set Next Destinies.  It has the attack Glinting Claw with the cost Lightning, Colorless, Colorless, the energy cost 3 and the damage of 50+ with the description: Flip a coin. If heads, this attack does 30 more damage. It has the attack Strong Volt with the cost Lightning, Lightning, Colorless, Colorless, the energy cost 4 and the damage of 150 with the description: Discard 2 Energy attached to this Pokemon. It has weakness against Fighting 2. ', "A Basic Pokemon Card of type Grass with the title Shuckle and 80 HP of rarity Uncommon from the set Rebel Clash and the flavor text: It stores berries inside its shell. To avoid attacks, it hides beneath rocks and remains completely still. It has the attack Berry Picking with the cost Colorless, the energy cost 1 with the description: Shuffle up to 5 basic Energy cards from your discard pile into your deck. It has the attack Bind with the cost Grass, Colorless, Colorless, the energy cost 3 and the damage of 50 with the description: Flip a coin. If heads, your opponent's Active Pokemon is now Paralyzed. It has weakness against Fire 2. "], 'name': ['Zekrom-EX', 'Shuckle'], 'hp': [180, 80], 'set_name': ['Next Destinies', 'Rebel Clash']}
# {'id': ['swsh12-87', 'sm115-10'], 'image_url': ['https://images.pokemontcg.io/swsh12/87_hires.png', 'https://images.pokemontcg.io/sm115/10_hires.png'], 'caption': ['A Basic Pokemon Card of type Psychic with the title Dreepy and 60 HP of rarity Common from the set Silver Tempest and the flavor text: After being reborn as a ghost Pokemon, Dreepy wanders the areas it used to inhabit back when it was alive in prehistoric seas. It has the attack Reckless Charge with the cost Psychic, the energy cost 1 and the damage of 30 with the description: This Pokemon also does 10 damage to itself. It has weakness against Darkness 2. It has resistance against Fighting -30. ', 'A Basic Pokemon Card of type Fire with the title Magmar and 90 HP of rarity Uncommon from the set Hidden Fates and the flavor text: Its entire body is burning. When it breathes, the temperature rises. When it sneezes, flames shoot out! It has the attack Fire Punch with the cost Fire, Fire, the energy cost 2 and the damage of 50. It has weakness against Water 2. '], 'name': ['Dreepy', 'Magmar'], 'hp': [60, 90], 'set_name': ['Silver Tempest', 'Hidden Fates']}
# {'id': ['xyp-XY198a', 'swsh9-72'], 'image_url': ['https://images.pokemontcg.io/xyp/XY198a_hires.png', 'https://images.pokemontcg.io/swsh9/72_hires.png'], 'caption': ["A MEGA, EX Pokemon Card of type Fire with the title M Camerupt-EX and 230 HP of rarity Promo evolved from Camerupt-EX from the set XY Black Star Promos.  It has the attack Magma Eruption with the cost Fire, Fire, Colorless, Colorless, the energy cost 4 and the damage of 120+ with the description: You may discard the top 3 cards of each player's deck. If you do, this attack does 40 more damage for each Energy card you discarded in this way. It has weakness against Water 2. ", 'A Basic Pokemon Card of type Fighting with the title Hitmontop and 100 HP of rarity Uncommon from the set Brilliant Stars and the flavor text: It launches kicks while spinning. If it spins at high speed, it may bore its way into the ground. It has the attack Spinning Draw with the cost Colorless, the energy cost 1 and the damage of 20 with the description: Draw a card. It has the attack Cyclone Kick with the cost Fighting, Fighting, Colorless, the energy cost 3 and the damage of 100. It has weakness against Psychic 2. '], 'name': ['M Camerupt-EX', 'Hitmontop'], 'hp': [230, 100], 'set_name': ['XY Black Star Promos', 'Brilliant Stars']}
# {'id': ['swsh6-107', 'sm3-14'], 'image_url': ['https://images.pokemontcg.io/swsh6/107_hires.png', 'https://images.pokemontcg.io/sm3/14_hires.png'], 'caption': ["A Stage 2 Pokemon Card of type Darkness with the title Scolipede and 160 HP of rarity Rare evolved from Whirlipede from the set Chilling Reign and the flavor text: With quick movements, it chases down its foes, attacking relentlessly with its horns until it prevails. It has the attack Poison Sting with the cost Darkness, the energy cost 1 and the damage of 50 with the description: Your opponent's Active Pokemon is now Poisoned. It has the attack Venoshock with the cost Darkness, Colorless, Colorless, the energy cost 3 and the damage of 100+ with the description: If your opponent's Active Pokemon is Poisoned, this attack does 120 more damage. It has weakness against Fighting 2. ", 'A Basic Pokemon Card of type Grass with the title Dewpider and 60 HP of rarity Common from the set Burning Shadows and the flavor text: It crawls onto the land in search of food. Its water bubble allows it to breathe and protects its soft head. It has the attack Ambush with the cost Grass, the energy cost 1 and the damage of 10+ with the description: Flip a coin. If heads, this attack does 10 more damage. It has weakness against Fire 2. '], 'name': ['Scolipede', 'Dewpider'], 'hp': [160, 60], 'set_name': ['Chilling Reign', 'Burning Shadows']}
# {'id': ['g1-RC29', 'bw3-6'], 'image_url': ['https://images.pokemontcg.io/g1/RC29_hires.png', 'https://images.pokemontcg.io/bw3/6_hires.png'], 'caption': ["A Basic Pokemon Card of type Lightning with the title Pikachu and 60 HP of rarity Rare Ultra from the set Generations and the flavor text: A yellow body is proof of good health. If you touch its bright-red cheeks, you'll see its shining, smiling face! It has the attack Nuzzle with the cost Colorless, the energy cost 1 with the description: Flip a coin. If heads, your opponent's Active Pokemon is now Paralyzed. It has the attack Quick Attack with the cost Colorless, Colorless, the energy cost 2 and the damage of 20+ with the description: Flip a coin. If heads, this attack does 10 more damage. It has weakness against Fighting 2. It has resistance against Metal -20. ", "A Basic Pokemon Card of type Grass with the title Dwebble and 60 HP of rarity Common from the set Noble Victories and the flavor text: The Pokemon can easily melt holes in hard rocks with a liquid secreted from its mouth. It has the attack Withdraw with the cost Colorless, the energy cost 1 with the description: Flip a coin. If heads, prevent all damage done to this Pokemon by attacks during your opponent's next turn. It has the attack Slash with the cost Grass, Colorless, the energy cost 2 and the damage of 20. It has weakness against Fire 2. "], 'name': ['Pikachu', 'Dwebble'], 'hp': [60, 60], 'set_name': ['Generations', 'Noble Victories']}
# {'id': ['ex1-44', 'sm8-30'], 'image_url': ['https://images.pokemontcg.io/ex1/44_hires.png', 'https://images.pokemontcg.io/sm8/30_hires.png'], 'caption': ['A Basic Pokemon Card of type Colorless with the title Skitty and 40 HP of rarity Uncommon from the set Ruby & Sapphire.  It has the attack Minor Errand-Running with the cost Colorless, the energy cost 1 with the description: Search your deck for 2 basic Energy cards, show them to your opponent, and put them into your hand. Shuffle your deck afterward. It has the attack Lullaby with the cost Colorless, the energy cost 1 and the damage of 10 with the description: The Defending Pokemon is now Asleep. It has weakness against Fighting 2. ', 'A Stage 1 Pokemon Card of type Grass with the title Ninjask and 80 HP of rarity Uncommon evolved from Nincada from the set Lost Thunder and the flavor text: Because it moves so quickly, it sometimes becomes unseeable. It congregates around tree sap. It has the attack X-Scissor with the cost Grass, the energy cost 1 and the damage of 40+ with the description: Flip a coin. If heads, this attack does 40 more damage. It has the ability Molting with the description: When you play this Pokemon from your hand to evolve 1 of your Pokemon during your turn, you may put a Shedinja from your discard pile onto your Bench. It has weakness against Fire 2. '], 'name': ['Skitty', 'Ninjask'], 'hp': [40, 80], 'set_name': ['Ruby & Sapphire', 'Lost Thunder']}
# TrainOutput(global_step=25, training_loss=1.4273568725585937, metrics={'train_runtime': 545.5301, 'train_samples_per_second': 0.733, 'train_steps_per_second': 0.046, 'total_flos': 1878661821522816.0, 'train_loss': 1.4273568725585937, 'epoch': 0.03})

# %% [markdown]
# ## Inference on fine-tuned model
# In this section, we test the deployed finetuned model sending a url of a pokemon card and text prompt and receiving the generated text in return.

# %%
url = "https://images.pokemontcg.io/pop6/2_hires.png"

# %%
prompts = [
    url,
    "Question: What's on the picture? Answer:",
]

# %%
do_inference(model, processor, prompts, max_new_tokens=100)
# Out:
# /usr/local/lib/python3.10/dist-packages/transformers/generation/configuration_utils.py:535: UserWarning: `num_beams` is set to 1. However, `early_stopping` is set to `True` -- this flag is only used in beam-based generation modes. You should set `num_beams>1` or unset `early_stopping`.
#   warnings.warn(
# Question: What's on the picture? Answer: This is ['Lucario-GX', 'Lucario']. A Basic Pokemon Card of type Fire with the title Lucario-GX and 90 HP of rarity Rare Holo from the set Unbound Legends and the flavor text: It's a Pokemon that can use its tail as a weapon. It's a Pokemon that can use its tail as a weapon. It evolves from Lucario when it is traded with
